# %%
print('Testing...')
if True:
    print("It's true!")
print('Done.')
# Out:
# Testing...
# It's true!
# Done.

# %%
print('Testing...')
if False:
    print('It\'s true!')
print('Done.')
# Out:
# Testing...
# Done.

# %%
x = 0
x==1
# Out:
# False

# %%
x = 0
print('Testing...')
if x==0:
    print('x is equal to 0')
if x>0:
    print('x is greater than 0')
if x>=0:
    print('x is greater than or equal to 0')
if x!=0:
    print('x is not equal to 0')
print('Done.')
# Out:
# Testing...
# x is equal to 0
# x is greater than or equal to 0
# Done.

# %%
x = 0
print('Testing...')
if not x==0:
    print('x is not equal to 0')
if not x>0:
    print('x is not greater than 0')
if not x>=0:
    print('x is not greater than or equal to 0')
if not x!=0:
    print('x is equal to 0')
print('Done.')
# Out:
# Testing...
# x is not greater than 0
# x is equal to 0
# Done.

# %%
x = 10
y = 10000000
(x is 10, y is 10000000)
# Out:
# <>:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /tmp/ipykernel_5421/2249791565.py:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   (x is 10, y is 10000000)
# /tmp/ipykernel_5421/2249791565.py:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   (x is 10, y is 10000000)
# (True, False)

# %%
2.0000000000000000000001 == 2
# Out:
# True

# %%
x = 10
y = 1

if x==0:
    y += 1
else:
    y -= 1
y
# Out:
# 0

# %%
x = -10
y = 1

if x==0:
    y += 1
elif x > 0:
    y -= 1
else:
    y *= 1
y
# Out:
# 1

# %%
x = 10
y = 1
z = (
    "leiruhgoqeilrugkhjnlqeairusKGdjhow neil5khjtgn "
    "qlwEISHFJN OSILDTZKURHJAGL"
    "NERDKFJHG PQE;AKLR TJNG S;D")
if x == 0:
    y += 1
    print("stuff")
elif x > 0:
    y -= 1
else:
    y *= 1
    print("x is less than 0")
y
# Out:
# 0

# %%
import os
import pathlib

# %%
home_dir = pathlib.Path.home()
print(home_dir)
home_dir
# Out:
# /home/jovyan
# PosixPath('/home/jovyan')

# %%
data_dir = os.path.join(home_dir, 'earth-analytics', 'data')
data_dir
# Out:
# '/home/jovyan/earth-analytics/data'

# %%
os.path.exists(data_dir)
# Out:
# True

# %%
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

# %%
os.makedirs(data_dir, exist_ok=True)
